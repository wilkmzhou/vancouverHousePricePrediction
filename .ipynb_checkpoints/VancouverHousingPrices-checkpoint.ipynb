# %% [markdown]
# ## Introduction
# ### Background Info
# ### Scientific Question
# **How well does Least Absolute Shrinkage and Selection Operator (LASSO) regression compare to Ordinary Least Squares (OLS) when predicting Vancouver housing prices?**
# ### Data Description
# The following table gives an overview of the data included in the dataset.
# | Variable Name | Variable Type | Description |
# |-----------------------|-----------------------|---------------------------------------|
# | Neighborhood | Categorical | The neighborhood the property is located in different cities in Vancouver |
# | Year | Integer | The year the market price of the property was assessed |
# | Season | Categorical | The season the market price of the property was assessed |
# | Property Type | Categorical  | The type of real estate (Triplex, Duplex, Condo, Townhouse, or House) |
# | Bedrooms | Integer | Number of bedrooms in property |
# | Bathrooms | Integer | Number of bathrooms in property |
# | Year Built | Integer | The year the property was constructed |
# | Renovation Year | Integer | The year the property was renovated (NaN if not) |
# | Garage Type | Categorical | Type of garage on property (Triple, Doubl , Single, or None) |
# | Square Footage (House) | Integer | The area of the house in square feet |
# | Square Footage (Land) | Integer | The area of the land in square feet |
# | Basement | Categorical | Determines whether there is a basement (Finished if there is, not finished if there is no basement) |
# | Legal Units | Integer | The number of structures part of the home |
# | Market Price | Integer | The market price of the property during that year and season |
#
#
# ### Source and Information

# %%
# Loading the necessary libraries
import pandas as pd
import numpy as np
import seaborn as sb
from sklearn import preprocessing
from sklearn.model_selection import train_test_split

# %%
rawHousingData = pd.read_csv("https://raw.githubusercontent.com/wilkmzhou/vancouverHousePricePrediction/refs/heads/main/synthetic_house_prices_20_years.csv")

pd.set_option("display.max_columns", 14)
pd.set_option("display.width", 500)

print(rawHousingData.head(n = 3))
print(len(rawHousingData))
print(rawHousingData.dtypes)
# Out:
#   Neighborhood  Year  Season Property Type  Bedrooms  Bathrooms  Year Built  Renovation Year Garage Type  Square Footage (House)  Square Footage (Land)      Basement  Legal Units  Market Price
# 0    Kitsilano  2004  Spring       Triplex         1          3        1954           2000.0      Double                    1308                   6742  Not Finished            2    1734587.40
# 1    Kitsilano  2004  Summer         Condo         3          1        2022              NaN      Single                    3947                   2592      Finished            0     951731.62
# 2    Kitsilano  2004    Fall         House         4          1        2006              NaN         NaN                     919                   9519  Not Finished            2    1782016.80
# 3520
# Neighborhood               object
# Year                        int64
# Season                     object
# Property Type              object
# Bedrooms                    int64
# Bathrooms                   int64
# Year Built                  int64
# Renovation Year           float64
# Garage Type                object
# Square Footage (House)      int64
# Square Footage (Land)       int64
# Basement                   object
# Legal Units                 int64
# Market Price              float64
# dtype: object

# %% [markdown]
# ### Exploratory Data Analysis

# %%
NrawHousingData = rawHousingData.select_dtypes(include = "number")
rawCorr = NrawHousingData.corr()
rawCorr.style.background_gradient(cmap = "coolwarm").format(precision = 3)
# Out:
# <style type="text/css">
# #T_59dc9_row0_col0, #T_59dc9_row1_col1, #T_59dc9_row2_col2, #T_59dc9_row3_col3, #T_59dc9_row4_col4, #T_59dc9_row5_col5, #T_59dc9_row6_col6, #T_59dc9_row7_col7, #T_59dc9_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col1, #T_59dc9_row3_col2, #T_59dc9_row4_col0, #T_59dc9_row4_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col2, #T_59dc9_row1_col0, #T_59dc9_row2_col7, #T_59dc9_row5_col6, #T_59dc9_row8_col4 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col3, #T_59dc9_row0_col6, #T_59dc9_row1_col2, #T_59dc9_row6_col1, #T_59dc9_row6_col8, #T_59dc9_row8_col2 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col4, #T_59dc9_row1_col3, #T_59dc9_row6_col3, #T_59dc9_row7_col6, #T_59dc9_row7_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col5 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col7, #T_59dc9_row1_col6, #T_59dc9_row1_col8, #T_59dc9_row2_col8, #T_59dc9_row5_col2, #T_59dc9_row5_col3, #T_59dc9_row5_col4, #T_59dc9_row5_col7, #T_59dc9_row7_col0, #T_59dc9_row7_col1, #T_59dc9_row7_col4, #T_59dc9_row7_col5 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_59dc9_row0_col8 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_59dc9_row1_col4, #T_59dc9_row1_col5, #T_59dc9_row2_col5, #T_59dc9_row3_col5, #T_59dc9_row3_col6, #T_59dc9_row4_col5, #T_59dc9_row5_col8, #T_59dc9_row6_col4, #T_59dc9_row7_col2, #T_59dc9_row8_col1, #T_59dc9_row8_col6 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_59dc9_row1_col7, #T_59dc9_row5_col1, #T_59dc9_row7_col3 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_59dc9_row2_col0, #T_59dc9_row5_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_59dc9_row2_col1, #T_59dc9_row3_col8, #T_59dc9_row4_col2, #T_59dc9_row4_col6, #T_59dc9_row4_col7, #T_59dc9_row6_col0, #T_59dc9_row6_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_59dc9_row2_col3, #T_59dc9_row8_col5, #T_59dc9_row8_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_59dc9_row2_col4, #T_59dc9_row3_col0, #T_59dc9_row3_col1, #T_59dc9_row4_col1, #T_59dc9_row8_col3 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_59dc9_row2_col6, #T_59dc9_row3_col7, #T_59dc9_row6_col7 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_59dc9_row3_col4, #T_59dc9_row4_col3 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_59dc9_row6_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_59dc9_row8_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# </style>
# <table id="T_59dc9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_59dc9_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_59dc9_level0_col1" class="col_heading level0 col1" >Bedrooms</th>
#       <th id="T_59dc9_level0_col2" class="col_heading level0 col2" >Bathrooms</th>
#       <th id="T_59dc9_level0_col3" class="col_heading level0 col3" >Year Built</th>
#       <th id="T_59dc9_level0_col4" class="col_heading level0 col4" >Renovation Year</th>
#       <th id="T_59dc9_level0_col5" class="col_heading level0 col5" >Square Footage (House)</th>
#       <th id="T_59dc9_level0_col6" class="col_heading level0 col6" >Square Footage (Land)</th>
#       <th id="T_59dc9_level0_col7" class="col_heading level0 col7" >Legal Units</th>
#       <th id="T_59dc9_level0_col8" class="col_heading level0 col8" >Market Price</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_59dc9_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_59dc9_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_59dc9_row0_col1" class="data row0 col1" >0.009</td>
#       <td id="T_59dc9_row0_col2" class="data row0 col2" >0.030</td>
#       <td id="T_59dc9_row0_col3" class="data row0 col3" >-0.006</td>
#       <td id="T_59dc9_row0_col4" class="data row0 col4" >-0.002</td>
#       <td id="T_59dc9_row0_col5" class="data row0 col5" >0.027</td>
#       <td id="T_59dc9_row0_col6" class="data row0 col6" >-0.012</td>
#       <td id="T_59dc9_row0_col7" class="data row0 col7" >-0.034</td>
#       <td id="T_59dc9_row0_col8" class="data row0 col8" >0.440</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row1" class="row_heading level0 row1" >Bedrooms</th>
#       <td id="T_59dc9_row1_col0" class="data row1 col0" >0.009</td>
#       <td id="T_59dc9_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_59dc9_row1_col2" class="data row1 col2" >-0.004</td>
#       <td id="T_59dc9_row1_col3" class="data row1 col3" >-0.000</td>
#       <td id="T_59dc9_row1_col4" class="data row1 col4" >0.003</td>
#       <td id="T_59dc9_row1_col5" class="data row1 col5" >-0.013</td>
#       <td id="T_59dc9_row1_col6" class="data row1 col6" >-0.018</td>
#       <td id="T_59dc9_row1_col7" class="data row1 col7" >-0.025</td>
#       <td id="T_59dc9_row1_col8" class="data row1 col8" >-0.007</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row2" class="row_heading level0 row2" >Bathrooms</th>
#       <td id="T_59dc9_row2_col0" class="data row2 col0" >0.030</td>
#       <td id="T_59dc9_row2_col1" class="data row2 col1" >-0.004</td>
#       <td id="T_59dc9_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_59dc9_row2_col3" class="data row2 col3" >0.023</td>
#       <td id="T_59dc9_row2_col4" class="data row2 col4" >0.012</td>
#       <td id="T_59dc9_row2_col5" class="data row2 col5" >-0.011</td>
#       <td id="T_59dc9_row2_col6" class="data row2 col6" >0.011</td>
#       <td id="T_59dc9_row2_col7" class="data row2 col7" >0.007</td>
#       <td id="T_59dc9_row2_col8" class="data row2 col8" >-0.003</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row3" class="row_heading level0 row3" >Year Built</th>
#       <td id="T_59dc9_row3_col0" class="data row3 col0" >-0.006</td>
#       <td id="T_59dc9_row3_col1" class="data row3 col1" >-0.000</td>
#       <td id="T_59dc9_row3_col2" class="data row3 col2" >0.023</td>
#       <td id="T_59dc9_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_59dc9_row3_col4" class="data row3 col4" >0.633</td>
#       <td id="T_59dc9_row3_col5" class="data row3 col5" >-0.014</td>
#       <td id="T_59dc9_row3_col6" class="data row3 col6" >-0.000</td>
#       <td id="T_59dc9_row3_col7" class="data row3 col7" >-0.005</td>
#       <td id="T_59dc9_row3_col8" class="data row3 col8" >0.012</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row4" class="row_heading level0 row4" >Renovation Year</th>
#       <td id="T_59dc9_row4_col0" class="data row4 col0" >-0.002</td>
#       <td id="T_59dc9_row4_col1" class="data row4 col1" >0.003</td>
#       <td id="T_59dc9_row4_col2" class="data row4 col2" >0.012</td>
#       <td id="T_59dc9_row4_col3" class="data row4 col3" >0.633</td>
#       <td id="T_59dc9_row4_col4" class="data row4 col4" >1.000</td>
#       <td id="T_59dc9_row4_col5" class="data row4 col5" >-0.014</td>
#       <td id="T_59dc9_row4_col6" class="data row4 col6" >0.006</td>
#       <td id="T_59dc9_row4_col7" class="data row4 col7" >-0.012</td>
#       <td id="T_59dc9_row4_col8" class="data row4 col8" >0.027</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row5" class="row_heading level0 row5" >Square Footage (House)</th>
#       <td id="T_59dc9_row5_col0" class="data row5 col0" >0.027</td>
#       <td id="T_59dc9_row5_col1" class="data row5 col1" >-0.013</td>
#       <td id="T_59dc9_row5_col2" class="data row5 col2" >-0.011</td>
#       <td id="T_59dc9_row5_col3" class="data row5 col3" >-0.014</td>
#       <td id="T_59dc9_row5_col4" class="data row5 col4" >-0.014</td>
#       <td id="T_59dc9_row5_col5" class="data row5 col5" >1.000</td>
#       <td id="T_59dc9_row5_col6" class="data row5 col6" >0.023</td>
#       <td id="T_59dc9_row5_col7" class="data row5 col7" >-0.030</td>
#       <td id="T_59dc9_row5_col8" class="data row5 col8" >0.009</td>
#     </tr>
#     <tr>
#       <th id="T_59dc9_level0_row6" class="row_heading level0 row6" >Square Footage (Land)</th>
#       <td id="T_59dc9_row6_col0" class="data row6 col0" >-0.012</td>
#       <td id="T_59dc9_row6_col1" class="data row6 col1" >

# %%
Sq_Mp_Neigh_Plot = sb.scatterplot(data = rawHousingData, x = "Square Footage (Land)", y = "Market Price", hue = "Neighborhood", alpha = 0.7)
sb.move_legend(Sq_Mp_Neigh_Plot, "upper left", bbox_to_anchor= (1,1), frameon = False, ncol = 4)
Sq_Mp_Neigh_Plot.set_ylabel("Market Price (in dollars)")
Sq_Mp_Neigh_Plot.set_title("Market Price vs Square Footage (Land) with Neighborhood Scatter Plot")
Sq_Mp_Neigh_Plot.ticklabel_format(style = "plain", axis = "y")

# %%
Year_Mp_Pt_Plot = sb.scatterplot(data = rawHousingData, x = "Year", y = "Market Price", hue = "Property Type", alpha = 0.7)

current_ticks = Year_Mp_Pt_Plot.get_xticks()
Year_Mp_Pt_Plot.set_xticks(current_ticks)
Year_Mp_Pt_Plot.set_xticklabels(Year_Mp_Pt_Plot.get_xticks().astype(int))

sb.move_legend(Year_Mp_Pt_Plot, "upper left", bbox_to_anchor= (1,1), frameon = False)
Year_Mp_Pt_Plot.ticklabel_format(style = "plain", axis = "y")
Year_Mp_Pt_Plot.set_title("Market Price vs Year with Property Type Scatter Plot")
Year_Mp_Pt_Plot.set_xlabel("Market Price Assessment Year")
Year_Mp_Pt_Plot.set_ylabel("Market Price (in dollars)")
# Out:
# Text(0, 0.5, 'Market Price (in dollars)')

# %%
rawHousingData["is_Renovated"] = rawHousingData["Renovation Year"].isnull().astype(int)
rawHousingData["adjusted_house_age"] = 2024 - rawHousingData[["Year Built", "Renovation Year"]].max(axis = 1)
rawHousingData["Garage Type"] = rawHousingData["Garage Type"].fillna("No Garage")
rawHousingData = rawHousingData.drop(columns =["Renovation Year"],axis = 1)


housingData = rawHousingData.dropna()
housingData = housingData.drop_duplicates()

print(housingData.head(n = 3))
print(len(housingData))
# Out:
#   Neighborhood  Year  Season Property Type  Bedrooms  Bathrooms  Year Built  ... Square Footage (House)  Square Footage (Land)      Basement Legal Units  Market Price  is_Renovated  adjusted_house_age
# 0    Kitsilano  2004  Spring       Triplex         1          3        1954  ...                   1308                   6742  Not Finished           2    1734587.40             0                24.0
# 1    Kitsilano  2004  Summer         Condo         3          1        2022  ...                   3947                   2592      Finished           0     951731.62             1                 2.0
# 2    Kitsilano  2004    Fall         House         4          1        2006  ...                    919                   9519  Not Finished           2    1782016.80             1                18.0
#
# [3 rows x 15 columns]
# 3520

# %%
NhousingData = housingData.select_dtypes(include = "number")
cleanCorr = NhousingData.corr()
cleanCorr.style.background_gradient(cmap = "coolwarm").format(precision = 3)
# Out:
# <style type="text/css">
# #T_4517e_row0_col0, #T_4517e_row1_col1, #T_4517e_row2_col2, #T_4517e_row3_col3, #T_4517e_row4_col4, #T_4517e_row5_col5, #T_4517e_row6_col6, #T_4517e_row7_col7, #T_4517e_row8_col8, #T_4517e_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col1, #T_4517e_row0_col8, #T_4517e_row2_col8, #T_4517e_row3_col2, #T_4517e_row9_col4 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col2, #T_4517e_row1_col0, #T_4517e_row2_col6, #T_4517e_row4_col5 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col3, #T_4517e_row1_col3, #T_4517e_row6_col3, #T_4517e_row6_col9 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_4517e_row0_col4 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col5, #T_4517e_row1_col2, #T_4517e_row2_col7, #T_4517e_row5_col1, #T_4517e_row7_col2, #T_4517e_row9_col5 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col6, #T_4517e_row1_col5, #T_4517e_row1_col7, #T_4517e_row1_col8, #T_4517e_row3_col9, #T_4517e_row4_col2, #T_4517e_row4_col6, #T_4517e_row5_col8, #T_4517e_row6_col0, #T_4517e_row6_col1, #T_4517e_row6_col4, #T_4517e_row8_col1, #T_4517e_row8_col5, #T_4517e_row8_col7, #T_4517e_row9_col3, #T_4517e_row9_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_4517e_row0_col7 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_4517e_row0_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_4517e_row1_col4, #T_4517e_row2_col4, #T_4517e_row3_col4, #T_4517e_row3_col5, #T_4517e_row6_col2, #T_4517e_row6_col7, #T_4517e_row7_col1, #T_4517e_row7_col5 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_4517e_row1_col6, #T_4517e_row4_col1, #T_4517e_row5_col7, #T_4517e_row6_col8, #T_4517e_row7_col8, #T_4517e_row9_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_4517e_row1_col9, #T_4517e_row4_col3 {
#   background-color: #c3d5f4;
#   color: #000000;
# }
# #T_4517e_row2_col0, #T_4517e_row4_col0 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_4517e_row2_col1, #T_4517e_row3_col7, #T_4517e_row4_col7, #T_4517e_row4_col8, #T_4517e_row5_col0, #T_4517e_row5_col2, #T_4517e_row8_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_4517e_row2_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_4517e_row2_col5, #T_4517e_row3_col6, #T_4517e_row5_col6, #T_4517e_row8_col4, #T_4517e_row9_col6 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_4517e_row2_col9, #T_4517e_row4_col9, #T_4517e_row5_col3 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_4517e_row3_col0, #T_4517e_row3_col1, #T_4517e_row8_col2 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_4517e_row3_col8 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_4517e_row5_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_4517e_row5_col9, #T_4517e_row7_col9, #T_4517e_row9_col8 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_4517e_row6_col5, #T_4517e_row9_col2 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_4517e_row7_col0 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_4517e_row7_col3 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_4517e_row7_col4, #T_4517e_row7_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_4517e_row8_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_4517e_row8_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_4517e_row8_col9 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_4517e_row9_col0 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_4517e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4517e_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_4517e_level0_col1" class="col_heading level0 col1" >Bedrooms</th>
#       <th id="T_4517e_level0_col2" class="col_heading level0 col2" >Bathrooms</th>
#       <th id="T_4517e_level0_col3" class="col_heading level0 col3" >Year Built</th>
#       <th id="T_4517e_level0_col4" class="col_heading level0 col4" >Square Footage (House)</th>
#       <th id="T_4517e_level0_col5" class="col_heading level0 col5" >Square Footage (Land)</th>
#       <th id="T_4517e_level0_col6" class="col_heading level0 col6" >Legal Units</th>
#       <th id="T_4517e_level0_col7" class="col_heading level0 col7" >Market Price</th>
#       <th id="T_4517e_level0_col8" class="col_heading level0 col8" >is_Renovated</th>
#       <th id="T_4517e_level0_col9" class="col_heading level0 col9" >adjusted_house_age</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4517e_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_4517e_row0_col0" class="data row0 col0" >1.000</td>
#       <td id="T_4517e_row0_col1" class="data row0 col1" >0.009</td>
#       <td id="T_4517e_row0_col2" class="data row0 col2" >0.030</td>
#       <td id="T_4517e_row0_col3" class="data row0 col3" >-0.006</td>
#       <td id="T_4517e_row0_col4" class="data row0 col4" >0.027</td>
#       <td id="T_4517e_row0_col5" class="data row0 col5" >-0.012</td>
#       <td id="T_4517e_row0_col6" class="data row0 col6" >-0.034</td>
#       <td id="T_4517e_row0_col7" class="data row0 col7" >0.440</td>
#       <td id="T_4517e_row0_col8" class="data row0 col8" >0.013</td>
#       <td id="T_4517e_row0_col9" class="data row0 col9" >0.018</td>
#     </tr>
#     <tr>
#       <th id="T_4517e_level0_row1" class="row_heading level0 row1" >Bedrooms</th>
#       <td id="T_4517e_row1_col0" class="data row1 col0" >0.009</td>
#       <td id="T_4517e_row1_col1" class="data row1 col1" >1.000</td>
#       <td id="T_4517e_row1_col2" class="data row1 col2" >-0.004</td>
#       <td id="T_4517e_row1_col3" class="data row1 col3" >-0.000</td>
#       <td id="T_4517e_row1_col4" class="data row1 col4" >-0.013</td>
#       <td id="T_4517e_row1_col5" class="data row1 col5" >-0.018</td>
#       <td id="T_4517e_row1_col6" class="data row1 col6" >-0.025</td>
#       <td id="T_4517e_row1_col7" class="data row1 col7" >-0.007</td>
#       <td id="T_4517e_row1_col8" class="data row1 col8" >-0.021</td>
#       <td id="T_4517e_row1_col9" class="data row1 col9" >-0.015</td>
#     </tr>
#     <tr>
#       <th id="T_4517e_level0_row2" class="row_heading level0 row2" >Bathrooms</th>
#       <td id="T_4517e_row2_col0" class="data row2 col0" >0.030</td>
#       <td id="T_4517e_row2_col1" class="data row2 col1" >-0.004</td>
#       <td id="T_4517e_row2_col2" class="data row2 col2" >1.000</td>
#       <td id="T_4517e_row2_col3" class="data row2 col3" >0.023</td>
#       <td id="T_4517e_row2_col4" class="data row2 col4" >-0.011</td>
#       <td id="T_4517e_row2_col5" class="data row2 col5" >0.011</td>
#       <td id="T_4517e_row2_col6" class="data row2 col6" >0.007</td>
#       <td id="T_4517e_row2_col7" class="data row2 col7" >-0.003</td>
#       <td id="T_4517e_row2_col8" class="data row2 col8" >0.014</td>
#       <td id="T_4517e_row2_col9" class="data row2 col9" >0.001</td>
#     </tr>
#     <tr>
#       <th id="T_4517e_level0_row3" class="row_heading level0 row3" >Year Built</th>
#       <td id="T_4517e_row3_col0" class="data row3 col0" >-0.006</td>
#       <td id="T_4517e_row3_col1" class="data row3 col1" >-0.000</td>
#       <td id="T_4517e_row3_col2" class="data row3 col2" >0.023</td>
#       <td id="T_4517e_row3_col3" class="data row3 col3" >1.000</td>
#       <td id="T_4517e_row3_col4" class="data row3 col4" >-0.014</td>
#       <td id="T_4517e_row3_col5" class="data row3 col5" >-0.000</td>
#       <td id="T_4517e_row3_col6" class="data row3 col6" >-0.005</td>
#       <td id="T_4517e_row3_col7" class="data row3 col7" >0.012</td>
#       <td id="T_4517e_row3_col8" class="data row3 col8" >0.210</td>
#       <td id="T_4517e_row3_col9" class="data row3 col9" >-0.718</td>
#     </tr>
#     <tr>
#       <th id="T_4517e_level0_row4" class="row_heading level0 row4" >Square Footage (House)</th>
#       <td id="T_4517e_row4_col0" class="data row4 col0" >0.027</td>
#       <td id="T_4517e_row4_col1" class="data row4 col1" >-0.013</td>
#       <td id="T_4517e_row4_col2" class="data row4 col2" >-0.011</td>
#       <td id="T_4517e_row4_col3" class="data row4 col3" >-0.014</td>
#       <td id

# %% [markdown]
# ## Dataset Preparations

# %%
housingData = housingData.sample(frac = 1).reset_index(drop = True)

print(housingData.head(n = 3))
print(len(housingData))
